# %% [markdown]
# # Cú pháp
#
# input(prompt)
#
# where:
#
#     prompt: chuỗi thông báo
#     Dữ liệu nhập vào đều là dạng str

# %%
a = input("Nhập vào một số:")
print("a = ", a)
# Out:
# Nhập vào một số: 123
# a =  123

# %%
LastName = input("Họ : ")
FirstName = input("Tên : ")
print(LastName, FirstName)
# Out:
# Họ :  Vũ
# Tên :  Linh
# Vũ Linh

# %%
type(LastName)
# Out:
# str

# %%
type(a)
# Out:
# str
